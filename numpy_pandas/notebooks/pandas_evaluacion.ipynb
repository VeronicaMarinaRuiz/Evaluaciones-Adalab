# %% [markdown]
# ## Ejercicios de Pandas

# %% [markdown]
# - Para la parte de Pandas usaremos el mismo conjunto de datos de música de Spotify, en concreto tendremos un conjunto de datos de canciones de varios artistas en el mundo y para cada canción está presente:
#
# Varias estadísticas de la versión musical en spotify, incluido el número de streams;
#
# Número de visualizaciones del vídeo musical oficial de la canción en youtube.
#
# - Las variables que tendremos en este dataframe son:
#
# Incluye 26 variables para cada una de las canciones recogidas de spotify. Estas variables se describen brevemente a continuación:
#
# · Track: nombre de la canción, tal y como aparece en la plataforma Spotify.
#
# · Artist: nombre del artista.
#
# · Url_spotify: Url de la canción.
#
# · Album: el álbum en el que se encuentra la canción en Spotify.
#
# · Album_type: indica si la canción se publica en Spotify como single o dentro de un álbum.
#
# · Uri: un enlace de Spotify utilizado para encontrar la canción a través de la API.
#
# · Danceability: describe lo adecuada que es una canción para bailar basándose en una combinación de elementos musicales como el tempo, la estabilidad del ritmo, la fuerza del compás y la regularidad general. Un valor de 0,0 es el menos bailable y 1,0 el más bailable.
#
# · Energy: es una medida de 0,0 a 1,0 y representa una medida perceptiva de intensidad y actividad. Normalmente, las pistas energéticas son rápidas, ruidosas y ruidosas. Por ejemplo, el death metal tiene mucha energía, mientras que un preludio de Bach tiene una puntuación baja en la escala. Las características perceptivas que contribuyen a este atributo incluyen el rango dinámico, el volumen percibido, el timbre, la velocidad de inicio y la entropía general.
#
# · Key: la clave de la pista. Los números enteros se asignan a los tonos utilizando la notación estándar Pitch Class. Por ejemplo, 0 = C, 1 = C♯/D♭, 2 = D, y así sucesivamente. Si no se detecta ninguna tonalidad, el valor es -1.
#
# · Loudness: la sonoridad global de una pista en decibelios (dB). Los valores de sonoridad se promedian en toda la pista y son útiles para comparar la sonoridad relativa de las pistas. La sonoridad es la cualidad de un sonido que es el principal correlato psicológico de la fuerza física (amplitud). Los valores suelen oscilar entre -60 y 0 db.
#
# · Speechiness: detecta la presencia de palabras habladas en una pista. Cuanto más exclusivamente hablada sea la grabación (por ejemplo, un programa de entrevistas, un audiolibro, poesía), más se acercará a 1,0 el valor del atributo. Los valores superiores a 0,66 describen pistas que probablemente estén compuestas en su totalidad por palabras habladas. Los valores entre 0,33 y 0,66 describen pistas que pueden contener tanto música como voz, ya sea en secciones o en capas, incluyendo casos como la música rap. Los valores por debajo de 0,33 representan probablemente música y otras pistas no habladas.
#
# · Acousticness: una medida de confianza de 0,0 a 1,0 para determinar si la pista es acústica. 1,0 representa una confianza alta en que la pista es acústica.
#
# · Instrumentalness: predice si una pista no contiene voces. Los sonidos "ooh" y "aah" se consideran instrumentales en este contexto. Las pistas de rap o spoken word son claramente "vocales". Cuanto más se acerque el valor de instrumental a 1,0, mayor será la probabilidad de que la canción no contenga voces. Los valores superiores a 0,5 representan pistas instrumentales, pero la confianza es mayor a medida que el valor se acerca a 1,0.
#
# · Liveness: detecta la presencia de público en la grabación. Los valores más altos representan una mayor probabilidad de que la pista se haya interpretado en directo. Un valor superior a 0,8 proporciona una gran probabilidad de que la pista sea en directo.
#
# · Valence: una medida de 0,0 a 1,0 que describe la positividad musical que transmite una pista. Las pistas con una valencia alta suenan más positivas (por ejemplo, felices, alegres, eufóricas), mientras que las pistas con una valencia baja suenan más negativas (por ejemplo, tristes, deprimidas, enfadadas).
#
# · Tempo: el tempo global estimado de una pista en pulsaciones por minuto (BPM). En terminología musical, el tempo es la velocidad o el ritmo de una pieza determinada y se deriva directamente de la duración media de los tiempos.
#
# · Duration_ms: duración de la pista en milisegundos.
#
# · Stream: número de streams de la canción en Spotify.
#
# · Url_youtube: url del vídeo enlazado a la canción en Youtube, si lo tiene.
#
# · Title: título del videoclip en Youtube.
#
# · Channel: nombre del canal que ha publicado el vídeo.
#
# · Views: número de vistas.
#
# · Likes: número de me gusta.
#
# · Comments: número de comentarios.
#
# · Description: descripción del vídeo en Youtube.
#
# · Licensed: Indica si el vídeo representa contenido con licencia, lo que significa que el contenido fue subido a un canal vinculado a un socio de contenido de Youtube y luego reclamado por dicho socio.
#
# · official_video: valor booleano que indica si el vídeo encontrado es el vídeo oficial de la canción.

# %% [markdown]
# Los ejercicios que os plantemos para esta parte de la evaluación son:
#
# 1. Importad Pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Código para que me muestre todas las columnas
pd.options.display.max_columns=None

# %% [markdown]
# 2. Exploración del conjunto de datos:
#
# - Cargad el fichero, al cargarlo os aparecerá una columna llamada "Unnamed: 0". Cargad el dataset sin que aparezca esta columna. Además realizad un análisis exploratorio que incluya:
#
# - Cuando leais el fichero, veremos que no podemos ver todas las columnas, utilizad el comando correcto para poder visualizarlas todas cuando hacemos un head
#
# - Primeras 5 filas del dataframe
#
# - Últimas 5 filas del dataframe
#
# - 10 filas aleatorias del dataframe
#
# - ¿Cuántas filas y columnas tenemos en el dataframe
#
# - ¿Cuáles son los tipos de los datos de cada columna del dataframe
#
# - ¿Cuántos valores nulos tenemos por columna?
#
# - ¿Tenemos filas duplicadas en el dataframe ?
#
# - Muestra los principales estadísticos para las columnas numéricas del dataframe
#
# - Muestra los principales estadísticos para las columnas categóricas del dataframe

# %%
# Trabajamos con un csv, por lo que uso el método pd.read_csv para abrir el archivo. Indico con index_col que la columna que quiero de índice está en el 0.  
df = pd.read_csv('../datos/Spotify_Youtube.csv', index_col = 0)
df.head(3)
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
#
#                                     Uri Danceability Energy  Key Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705  6,0   -6,679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG        0,676  0,703  8,0   -5,815
# ...

# %%
df.head(2)
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              Track          Album Album_type  \
# 0   Feel Good Inc.     Demon Days      album
# 1  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri Danceability Energy  Key Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705  6,0   -6,679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG        0,676  0,703  8,0   -5,815
#
#   Speechiness Acousticness Instrumentalness  Liveness  Valence    Tempo  \
# 0       0,177      0,00836          0,00233    0.6130    0.772  138.559
# 1      0,0302       0,0869         0,000687    0.0463    0.852   92.761
#
#    Duration_ms                                  Url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
#
# ...

# %%
# Función que me va a realizar una explotación del dataframe. Recibe un parámetro que es el dataframe que queremos explorar.
def exploracion(dataframe):
    """
    Esta función realiza una exploración de los principales estadísticos de un dataframe.
    Args:
        dataframe: el dataframe a analizar.
    Returns: None
    """
    print(f'Primeras cinco filas del dataframe:')
    display(df.head())
    print('---------------')
    print(f'Últimas cinco filas del dataframe:')
    display(df.tail())
    print('---------------')
    print(f'Diez filas del dataframe:')
    display(df.sample(10))
    print('---------------')
    print(f'El número de filas y columnas del dataframe:')
    display(df.shape)
    print('---------------')
    print(f'Tipo de dato de las columnas del dataframe:')
    display(df.dtypes)
    print('---------------')
    print('Valores nulos por columna del dataframe')
    display(df.isnull().sum().reset_index())
    print('---------------')
    print('Filas duplicadas del dataframe')
    display(df.duplicated().sum())
    print('---------------')
    print(f'Principales estadísticos para las columnas numéricas del dataframe:')
    display(df.describe())
    print('---------------')
    print(f'Principales estadísticos para las columnas categóricas del dataframe:')
    display(df.describe(include = object))

# %%
exploracion('../datos/Spotify_Youtube.csv')
# Out:
# Primeras cinco filas del dataframe:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %% [markdown]
# ---

# %% [markdown]
# 3. Preparación de los datos:
#
# Los nombres de las columnas empiezan con mayúsculas, poned todos los nombres de las columnas en minúsculas.

# %%
# Para ver el nombre de las columnas
df.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'Official_video', 'Stream'],
#       dtype='object')

# %%
# Creo un diccionario de comprensión y lo igualo a una variable, la key serán los nombres originales y el value el mismo nombre, pero en minúsculas .lower().
nombres_modificados = {column : column.lower() for column in df.columns}

# Utilizo el método rename() para cambiar los nombres de las columnas con la condición de nuestro diccionario. Incluyo inplace=True para modificar el dataframe original.
df.rename(columns = nombres_modificados, inplace = True)

df.columns
# Out:
# Index(['artist', 'url_spotify', 'track', 'album', 'album_type', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'url_youtube', 'title', 'channel', 'views', 'likes',
#        'comments', 'description', 'licensed', 'official_video', 'stream'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# - Haciendo el análisis exploratorio nos deberíamos haber dado cuenta de que algunas de las variables (danceability, energy, key, loudness, speechiness, acousticness, instrumentalness) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Cread una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.
#
# - Después de haber hecho los cambios, chequead los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, cread otra función o modificar la anterior para que sean de tipo float.

# %%
# Funcion para cambiar las columnas con datos erróneos. Con el método replace() cambiamos esas comas por puntos y las convertimos a float.
def cambiar_tipo(columna):
    """
    Esta función cambia el tipo de las columnas a float y reemplaza las comas por puntos.
    Args:
        columna(str): la columna a modificar.
    Returns: devuelve la columna modificada.
    """
    try:
        return float(columna.replace(',', '.'))
    except:
        return columna

# %%
# Creo una lista con las columnas a cambiar, iteramos por cada una de ellas con el for y con el método apply() aplicamos la función.
columnas_a_cambiar = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness']

for col in columnas_a_cambiar:
    df[col] = df[col].apply(cambiar_tipo)

# %%
# Antes eran de tipo object y ahora son de tipo float64
df.dtypes.reset_index()
# Out:
#                index        0
# 0             artist   object
# 1        url_spotify   object
# 2              track   object
# 3              album   object
# 4         album_type   object
# 5                uri   object
# 6       danceability  float64
# 7             energy  float64
# 8                key  float64
# 9           loudness  float64
# 10       speechiness  float64
# 11      acousticness  float64
# 12  instrumentalness  float64
# 13          liveness  float64
# 14           valence  float64
# 15             tempo  float64
# 16       duration_ms  float64
# 17       url_youtube   object
# 18             title   object
# 19           channel   object
# 20             views  float64
# 21             likes  float64
# 22          comments  float64
# 23       description   object
# 24          licensed   object
# 25    official_video   object
# 26            stream  float64

# %% [markdown]
# ---

# %% [markdown]
# - Hay algunas canciones cuyo título está en mayúsculas. Crea una función para que todos los títulos estén en minúscula. Haced lo mismo para las columnas de "title" y "album".

# %% [markdown]
# def sumar_numeros(a,b):
#    """
#    Esta función suma dos numeros # primero tenemos que poner brevemente que es lo que hace la función
#   Args: # ponemos los parámetros que recibe la función
#        a (int o float): el primer número que queremos sumar. # aquí ponemos el  nombre del parámetro de la función y el tipo de dato entre paréntesis, seguido de una pequeña descripción
#        b (int o float): el segundo número que queremos sumar. # hacemos los mismo que en el anterior
#    Returns: esta función devuelve la suma de los dos parámetros pasados por el usuario
#    """
#    return a +b

# %%
# Función para modificar a minúsculas, si el valor es nulo, devuelve un nulo.
def minuscula(columna):
    """
    Esta función cambia el tipo de las columnas a letras minúsculas.
    Args:
        columna(str): la columna a modificar.
    Returns: devuelve la columna modificada.
    """
    try:
       return columna.lower()
    except:
        return np.nan

# %%
# Creo una lista con las columnas que tenemos que modificar.
columnas = ['title', 'album']

for col in columnas:
    df[col] = df[col].apply(minuscula)

# %%
df.sample(5)
# Out:
#                        artist  \
# 11450    Bring Me The Horizon
# 9966              Simple Plan
# 18852  Ski Mask The Slump God
# 15175             Leo Santana
# 6025               Commodores
#
#                                              url_spotify  \
# 11450  https://open.spotify.com/artist/1Ffb6ejR6Fe5Ia...
# 9966   https://open.spotify.com/artist/2p4FqHnazRucYQ...
# 18852  https://open.spotify.com/artist/2rhFzFmezpnW82...
# 15175  https://open.spotify.com/artist/7KVJCU4z5L4EUH...
# 6025   https://open.spotify.com/artist/6twIAGnYuIT1pn...
#
#                        track  \
# 11450  Can You Feel My Heart
# 9966          I'm Just a Kid
# 18852       Take A Step Back
# 15175                Encaixa
# 6025      Three Times A Lady
#
#                                                    album   album_type  \
# 11450                     sempiternal (expanded edition)        album
# 9966   no pads, no helmets...just balls (15th anniver...        album
# ...

# %% [markdown]
# ---

# %% [markdown]
# - Algunos de los artistas tienen símbolos raros, en concreto el símbolo $. Cread una función que nos elimine este símbolo de los nombres de los artistas.

# %%
# Utilizo el método constains() para que en la columna artist me comprube si cada elemento contiene el símbolo $. Como me devuelve un boleano, filtro por la columna y con 
# value_counts() me cuenta las veces que aparece cada valor unico. 
df[df['artist'].str.contains('\$')]['artist'].value_counts()
# Out:
# Too $hort        10
# Curren$y         10
# Ty Dolla $ign    10
# A$AP Rocky       10
# A$AP Ferg        10
# Joey Bada$$      10
# $uicideboy$      10
# bbno$            10
# $NOT             10
# Name: artist, dtype: int64

# %%
# Función para cambiar el símbolo $ por una S, ya que forma parte del nombre de esos artistas.
def cambiar_simbolo(columna):
    """
    Esta función cambia el símbolo $ por una S.
    Args:
        columna(str): la columna a modificar.
    Returns: devuelve la columna modificada.
    """
    try:
        return columna.replace('$', 'S') 
    except:
        return columna

# %%
# Con el apply() aplico la función para modificar esos elementos
df['artist'] = df['artist'].apply(cambiar_simbolo)

# %%
# Compruebo si ya no hay ningún nombre con el símbolo.
df[df['artist'].str.contains('\$')]['artist'].value_counts()
# Out:
# Series([], Name: artist, dtype: int64)

# %%
#Compruebo si está cambiado por una S, por ejem con Too Short.
df[df['artist'].str.contains('Too Short')]['artist'].value_counts()
# Out:
# Too Short    10
# Name: artist, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# 4. Filtrado de datos y Visualización:
#
# ¿Cuáles son los valores únicos de la columna "album_type"? Cread tres dataframes diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
# Con el unique() compruebo los valores únicos de la columna, son tres.
df['album_type'].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
# Dataframe de album. Con el método shape() y el índice 0 que son las filas.
df_album = df[df['album_type'] == 'album']
print(f'Tenemos {df_album.shape[0]} canciones de tipo album')

df_album.head(1)
# Out:
# Tenemos 14926 canciones de tipo album
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             track       album album_type  \
# 0  Feel Good Inc.  demon days      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.177       0.00836           0.00233     0.613    0.772  138.559
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         title   channel        views  \
# 0  gorillaz - feel good inc. (official video)  Gorillaz  693555221.0
#
#        likes  comments                                        description  \
# ...

# %%
# Dataframe de single. Con el método shape() y el índice 0 que son las filas.
df_single = df[df['album_type'] == 'single']
print(f'Tenemos {df_single.shape[0]} canciones de tipo single')

df_single.head(1)
# Out:
# Tenemos 5004 canciones de tipo single
#      artist                                        url_spotify  \
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 2  New Gold (feat. Tame Impala and Bootie Brown)
#
#                                            album album_type  \
# 2  new gold (feat. tame impala and bootie brown)     single
#
#                                     uri  danceability  energy  key  loudness  \
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923  1.0     -3.93
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2       0.0522        0.0425            0.0469     0.116    0.551  108.014
#
#    duration_ms                                  url_youtube  \
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
#
#                                                title   channel      views  \
# ...

# %%
# Dataframe de compilation. Con el método shape() y el índice 0 que son las filas.
df_compilation = df[df['album_type'] == 'compilation']
print(f'Tenemos {df_compilation.shape[0]} canciones de tipo compilation')

df_compilation.head(1)
# Out:
# Tenemos 788 canciones de tipo compilation
#       artist                                        url_spotify  \
# 154  Shakira  https://open.spotify.com/artist/0EmeFodog0BfCg...
#
#                                                  track  \
# 154  Waka Waka (This Time for Africa) [The Official...
#
#                                                  album   album_type  \
# 154  listen up! the official 2010 fifa world cup album  compilation
#
#                                       uri  danceability  energy  key  \
# 154  spotify:track:6bNB5gxFX6Q87DbQWb8OWZ         0.758   0.871  2.0
#
#      loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 154    -6.408        0.147        0.0062               0.0    0.0663    0.753
#
#        tempo  duration_ms                                  url_youtube  \
# 154  126.994     202627.0  https://www.youtube.com/watch?v=pRpeEdMmmQ0
#
#                                                  title      channel  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# - Usando el dataframe de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Mostrad los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordenar los resultados de mayor a menor en base a la media.

# %%
# Utilizo el método groupby() para agrupar por la columna 'artist' y calcular la media y la desviación estándar de cada columna que piden para cada artista.
# Por último, con el método sort_values() ordena los resultados agrupados en función de la media más alta.
df_danceability = df_album.groupby('artist', dropna = True)['danceability'].agg(['mean', 'std']).sort_values('mean', ascending=False)
df_danceability.head()
# Out:
#                mean       std
# artist
# Latto      0.922333  0.014503
# Murda      0.911500  0.030406
# Jon Z      0.886000  0.015556
# Blueface   0.885000  0.043782
# Jung Kook  0.881000       NaN

# %%
# Columna 'acousticness'
df_acousticness = df_album.groupby('artist', dropna = True)['acousticness'].agg(['mean', 'std']).sort_values('mean', ascending=False)
df_acousticness.head()
# Out:
#                      mean       std
# artist
# Claude Debussy   0.993714  0.001380
# Robert Schumann  0.993444  0.004902
# Franz Schubert   0.989500  0.005237
# Edvard Grieg     0.989500  0.007863
# Frédéric Chopin  0.989286  0.004071

# %%
# Columna 'speechiness'
df_speechiness = df_album.groupby('artist', dropna = True)['speechiness'].agg(['mean', 'std']).sort_values('mean', ascending=False)
df_speechiness.head()
# Out:
#                           mean       std
# artist
# Sir Arthur Conan Doyle  0.9523  0.008845
# Bibi Blocksberg         0.9453  0.011879
# Sherlock Holmes         0.9393  0.015833
# TKKG                    0.9193  0.023542
# Fünf Freunde            0.9062  0.048960

# %% [markdown]
# ---

# %% [markdown]
# - Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, querremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:
#
# Agrupar por artista y calcular la media de visitas y de likes.

# %% [markdown]
# Quedaros con los 10 artistas que más visitas han tenido.

# %%
# Agrupo por la columna 'artist' y le digo que me sume todas las visitas para cada artista y que me ordene los resultados en ascendente para que salgan los que tienen más visitas.
# Con iloc selecciono los primeros 10.
df_mas_visitas = df.groupby('artist')['views'].sum().sort_values(ascending = False).iloc[:10].reset_index()
df_mas_visitas
# Out:
#                     artist         views
# 0               Ed Sheeran  1.546021e+10
# 1                CoComelon  1.460167e+10
# 2               Katy Perry  1.312063e+10
# 3             Charlie Puth  1.216759e+10
# 4               Luis Fonsi  1.162811e+10
# 5            Justin Bieber  1.099106e+10
# 6             Daddy Yankee  1.087193e+10
# 7               Bruno Mars  1.024092e+10
# 8  Macklemore & Ryan Lewis  1.012206e+10
# 9                 Coldplay  9.997278e+09

# %% [markdown]
# Quedaros con los 10 artistas que más likes han tenido.

# %%
# Agrupo por la columna 'artist' y le digo que me sume todas las visitas para cada artista y que me ordene los resultados en ascendente para que salgan los que tienen más likes.
# Con iloc selecciono los primeros 10.
df_mas_likes = df.groupby('artist')['likes'].sum().sort_values(ascending = False).iloc[:10].reset_index()
df_mas_likes
# Out:
#             artist        likes
# 0              BTS  139403808.0
# 1        BLACKPINK  132302505.0
# 2     Charlie Puth   86336925.0
# 3       Ed Sheeran   83543319.0
# 4    Justin Bieber   78584348.0
# 5    Billie Eilish   73338537.0
# 6  Imagine Dragons   72274477.0
# 7      Alan Walker   67977702.0
# 8         DJ Snake   67775831.0
# 9       Luis Fonsi   66908489.0

# %% [markdown]
# Haced un subplot, donde en uno tengamos los 10 artistas con más likes y en el otro los 10 artistas con mas views.

# %%
# Gráfica: uso un bartplot porque tengo una variable categórica y otra numérica. Quería las barras horizontales, por lo que en los ejes intercambié las variables.
fig, axes = plt.subplots(ncols = 1, nrows = 2, figsize = (10,11))

sns.barplot(x = 'views', y = 'artist', data = df_mas_visitas, ax = axes[0], palette = 'mako')
axes[0].set_title('Los 10 artistas con más visitas en Spotify', fontweight = 'bold', fontsize = 15)
axes[0].set_xlabel('Visitas', fontweight = 'bold', fontsize = 10)
axes[0].set_ylabel('Artista', fontweight = 'bold', fontsize = 10)

sns.barplot(x = 'likes', y = 'artist', data = df_mas_likes, ax = axes[1], palette = 'rocket')
axes[1].set_title('Los 10 artistas con más likes en Spotify', fontweight = 'bold', fontsize = 15)
axes[1].set_xlabel('Likes', fontweight = 'bold', fontsize = 10)
axes[1].set_ylabel('Artista', fontweight = 'bold', fontsize = 10)

fig.suptitle('Los 10 Artistas de Spotify con más Visitas y Likes', color = 'black', fontweight = 'bold', fontsize = 20);

# %% [markdown]
# Conclusiones:
# - Según la muestra que tenemos, en ambas gráficas podemos observar que independientemente de las visitas que tenga cada artista, no siempre van a ser los que más likes tengan.
# - Por ejemplo, BTS y BLACKPINK son los dos artista con mayor número de likes, pero no aparecen entre los 10 artistas con más visualizaciones.
# - Por otro lado, tenemos artistas como Ed Sheeran, Charlie Puth, Justin Bieber y Luis Fonsi que están en ambas gráficas, por lo que si hay relación entre el nº de visitas y el nº de likes que han recibido.

# %% [markdown]
# ---

# %% [markdown]
# BONUS: Haced lo mismo para los datos de tipo "single".

# %%
# Creo un dataframe que filtre solo por el tipo de album que sea single.
df_tipo_single = df[df['album_type'] == 'single']
df_tipo_single.head(2)
# Out:
#      artist                                        url_spotify  \
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                track  \
# 2      New Gold (feat. Tame Impala and Bootie Brown)
# 6  New Gold (feat. Tame Impala and Bootie Brown) ...
#
#                                                album album_type  \
# 2      new gold (feat. tame impala and bootie brown)     single
# 6  new gold (feat. tame impala and bootie brown) ...     single
#
#                                     uri  danceability  energy  key  loudness  \
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923  1.0    -3.930
# 6  spotify:track:2c3KCGq6UojB2c8UAFrRON         0.716   0.897  4.0    -7.185
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2       0.0522        0.0425            0.0469     0.116    0.551  108.014
# ...

# %%
# Agrupo por la columna 'artist' y le digo que me sume todas las visitas para cada artista y que me ordene los resultados en ascendente para que salgan los que tienen más likes
# de tipo de album 'single'
df_mas_visitas_single = df_tipo_single.groupby('artist')['views'].mean().sort_values(ascending = False).iloc[:10].reset_index()
df_mas_visitas_single
# Out:
#                     artist         views
# 0             Charlie Puth  2.935089e+09
# 1                  Rihanna  2.626030e+09
# 2                      PSY  2.520605e+09
# 3        Twenty One Pilots  1.987867e+09
# 4              Wiz Khalifa  1.690387e+09
# 5                BLACKPINK  1.465903e+09
# 6            Calvin Harris  1.371673e+09
# 7             Daddy Yankee  1.317749e+09
# 8          Christina Perri  1.107727e+09
# 9  Macklemore & Ryan Lewis  1.012206e+09

# %%
# Agrupo por la columna 'artist' y le digo que me sume los likes para cada artista y que me ordene los resultados en ascendente para que salgan los que tienen más likes
# de tipo de album 'single'
df_mas_likes_single = df_tipo_single.groupby('artist')['likes'].mean().sort_values(ascending = False).iloc[:10].reset_index()
df_mas_likes_single
# Out:
#               artist         likes
# 0       Charlie Puth  2.087347e+07
# 1          BLACKPINK  1.659181e+07
# 2  Twenty One Pilots  1.500336e+07
# 3                PSY  1.439684e+07
# 4   Childish Gambino  1.233227e+07
# 5        Wiz Khalifa  1.194763e+07
# 6             j-hope  1.177462e+07
# 7            Rihanna  1.060366e+07
# 8                BTS  7.514177e+06
# 9           Bastille  7.028406e+06

# %%
# Gráfica:
fig, axes = plt.subplots(ncols = 1, nrows = 2, figsize = (10,11))

sns.barplot(x = 'views', y = 'artist', data = df_mas_visitas_single, ax = axes[0], palette = 'mako')
axes[0].set_title('Los 10 artistas con más visitas en Spotify del tipo de album Single', fontweight = 'bold', fontsize = 15)
axes[0].set_xlabel('Visitas', fontweight = 'bold', fontsize = 10)
axes[0].set_ylabel('Artista', fontweight = 'bold', fontsize = 10)

sns.barplot(x = 'likes', y = 'artist', data = df_mas_likes_single, ax = axes[1], palette = 'rocket')
axes[1].set_title('Los 10 artistas con más likes en Spotify del tipo de album Single', fontweight = 'bold', fontsize = 15)
axes[1].set_xlabel('Likes', fontweight = 'bold', fontsize = 10)
axes[1].set_ylabel('Artista', fontweight = 'bold', fontsize = 10)

fig.suptitle('Los 10 Artistas de Spotify con más Visitas y Likes (Tipo: Single)', color = 'black', fontweight = 'bold', fontsize = 18);

# %% [markdown]
# Conclusiones:
# - Según la muestra que tenemos, en ambas gráficas podemos observar que independientemente de las visitas que tenga cada artista, no siempre van a ser los que más likes tengan igual que en las gráficas anteriores.
# - Por ejemplo, tenemos a Charlie Puth que si coincide que es el artista con mayor número de visitas y de likes, por lo que hay relación.
# - Por otro lado, tenemos artistas como Rihanna, PSY, BLACKPINK y Wiz Khalifa que están en ambas gráficas, por lo que si hay relación entre el nº de visitas y el nº de likes que han recibido.

# %% [markdown]
# ---

# %% [markdown]
# - Ahora queremos analizar la colaboración entre artistas en la industria musical, se tienen datos de las colaboraciones realizadas en los últimos años. Se desea conocer cuáles son los artistas que han colaborado en mayor cantidad de canciones y generar un ranking con los diez primeros. ¿Qué artistas con los que más colaboraciones tienen? Para esto tendréis que:
#
# Filtrad los datos para quedaros solo con aquellos datos donde en la columna "track" tengamos "feat".

# %%
# Creo un dataframe de las colaboraciones que contengan feat. 
df_colaboracion = df[df['track'].str.contains('feat', case = False)]
df_colaboracion.head(2)
# Out:
#      artist                                        url_spotify  \
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                track  \
# 2      New Gold (feat. Tame Impala and Bootie Brown)
# 6  New Gold (feat. Tame Impala and Bootie Brown) ...
#
#                                                album album_type  \
# 2      new gold (feat. tame impala and bootie brown)     single
# 6  new gold (feat. tame impala and bootie brown) ...     single
#
#                                     uri  danceability  energy  key  loudness  \
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923  1.0    -3.930
# 6  spotify:track:2c3KCGq6UojB2c8UAFrRON         0.716   0.897  4.0    -7.185
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2       0.0522        0.0425            0.0469     0.116    0.551  108.014
# ...

# %% [markdown]
# Contad cuantas canciones tiene cada artista utilizando el dataframe generado en el paso anterior.

# %%
# Creo un dataframe con las canciones con más colaboraciones de cada artista 
df_num_canciones = df_colaboracion['artist'].value_counts().iloc[:10].reset_index()
df_num_canciones
# Out:
#            index  artist
# 0        Juicy J      10
# 1     Macklemore      10
# 2  Bibi und Tina      10
# 3      DJ Khaled       9
# 4  Ty Dolla Sign       9
# 5   Wu-Tang Clan       9
# 6           Wale       8
# 7         Wizkid       8
# 8    Mark Ronson       8
# 9          B.o.B       8

# %% [markdown]
# Mostrad los resultados en una gráfica, seleccionado los 10 artistas con más colaboraciones.

# %%
# Gráfica: elijo la misma que en el anterior apartado.
plt.figure(figsize = (10, 5))

sns.barplot(x = 'artist', y = 'index', data = df_num_canciones, palette = 'crest')
plt.title('Los 10 artistas con más colaboraciones en Spotify', fontweight = 'bold', fontsize = 15)
plt.xlabel('Número de colaboraciones', fontweight = 'bold', fontsize = 10)
plt.ylabel('Artista', fontweight = 'bold', fontsize = 10);

# %% [markdown]
# Deberéis contestar a las siguientes preguntas:
#
# ¿Cuáles son los diez artistas que más han colaborado según los datos que tenemos?

# %% [markdown]
# Los diez artistas que más han colaborado son Juicy J, Macklemore, Bibi und Tina, DJ Khaled, Ty Dolla Sign, Wu-Tang Clan, Wale, Wizkid, Mark Ronson y B.o.B.

# %% [markdown]
# ¿Cuál es el número de canciones en los que ha colaborado el artista que ocupa el primer lugar en el ranking?

# %% [markdown]
# Los artistas que ocupan el primer lugar en el ranking son Juicy J, Macklemore y Bibi und Tina que han colaborado en 10 canciones cada uno.

# %% [markdown]
# ¿Cuál es el artista que ocupa el décimo lugar en el ranking y en cuántas canciones ha colaborado?

# %% [markdown]
# El artista que ocupan el décimo lugar en el ranking es B.o.B que ha colaborado en 8 canciones, pero son las mismas colaboraciones que los otros tres artistas que tiene delante, que son Wale, Wizkid, Mark Ronson.

# %% [markdown]
# ---

# %% [markdown]
# - Utilizando el dataframe original, queremos explorar si el tipo de álbum influye en la cantidad de vistas que recibe en una plataforma de transmisión de música. Para ello, debemos generar un boxplot con las variables necesarias y responder las siguientes preguntas:

# %%
# Gráfica:
plt.figure(figsize = (10, 5))

fig = sns.boxplot(x = 'views', y = 'album_type', data = df)

fig.set(xlabel = 'Número de visitas (millones)')
fig.set(ylabel = 'Tipo dea album')

fig.set_title('Cantidad de visitas por tipo de album');

# %% [markdown]
# Como la visualización no está muy clara porque el rango es muy alto (unas 800 millones de visitas), limito los ejes de los datos para que estén más ampliados y poder ver mejor el análisis:

# %%
plt.figure(figsize = (8, 7))

fig = sns.boxplot(x = 'album_type', y = 'views', data = df)

fig.set(xlabel = 'Tipo de Album')
fig.set(ylabel = 'Número de visitas (millones)')

fig.set_title('Cantidad de visitas por tipo de album')

# Limito los ejes
plt.ylim(0, 190000000);

# %%
# Datagrame con los estadísticos de las visitas por cada tipo de album por entenderlo mejor.
df_visitas_tipo_album = df.groupby('album_type')['views'].describe()
df_visitas_tipo_album
# Out:
#                count          mean           std   min         25%  \
# album_type
# album        14619.0  9.842739e+07  2.858933e+08   0.0  2052173.00
# compilation    769.0  7.961832e+07  2.196741e+08  71.0   656414.00
# single        4860.0  8.269886e+07  2.461023e+08  28.0  1374965.25
#
#                     50%          75%           max
# album_type
# album        15781710.0  72642342.50  8.079649e+09
# compilation   9569629.0  63125368.00  3.463816e+09
# single       11324830.0  63286504.75  5.773798e+09

# %% [markdown]
# ¿Qué tipo de álbumes tienden a tener más vistas en promedio?

# %% [markdown]
# - El album de tipo 'album' es el que destaca, el que tiene mayor número de visitas y está más alejado en cuanto a la media. El tipo 'album' tiene una media de algo menos de 20 millones de visitas, seguido del tipo 'single' que está alrededor de los 10 millones y, por último, de tipo 'compilation' con un poco menos.

# %% [markdown]
# ¿Hay algún tipo de álbumes que tenga una mayor dispersión en las vistas recibidas?

# %% [markdown]
# - El tipo de album con una mayor dispersión en las visitas es el de tipo 'album', ya que el rango intercuartílico (la caja) es mayor con respecto a las de tipo 'single' y 'compilation, que son prácticamente iguales.

# %% [markdown]
# ¿Existen valores atípicos (outliers) en alguna categoría de álbumes?

# %% [markdown]
# - En las tres categorías de la muestra, podemos observar que tienen muchos valores atípicos (outliers) que se encuentran fuera de los bigotes del boxplot. Algunos de ellos, se extienden hasta los 8 millones de visitas en el caso de tipo 'album'; hasta los casi 6 millones en los de tipo 'single'; y hasta los 3,5 millones en los de tipo 'compilation'.

# %% [markdown]
# ¿Qué conclusión se puede obtener sobre la relación entre el tipo de álbum y la cantidad de vistas recibidas?

# %% [markdown]
# - El tipo de album que tiene una mediana más alta y menos dispersión de las visitas recibidas (aunque sean muy parecidas) es el de 'album'. Lo que significa que tiende a recibir más visitas en promedio y es más popular que los otros dos tipos. Aún asi, como en los tres tipos tenemos muchos valores atípicos, esto puede sugerir que algunas canciones llegan a ser muy populares y obtienen muchas visitas, dando igual del tipo que sean, aunque destaquen un poco más las que son de tipo 'album', ya que tiene la canción con el mayor número de visualizaciones.
